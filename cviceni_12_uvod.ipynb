# %% [markdown]
# # Moje první analýza
#
# Tento notebook procvičuje práci s Jupyter Notebooky, numpy a matplotlib.

# %%
# automatický výstup poslední hodnoty v buňce
jmeno = "Jupyter"
verze = 4.2
verze
# Out:
# 4.2

# %%
# zkus nápovědu – spusť a prohlédni si výstup
len?

# %%
# vypiš balíčky nainstalované v projektu
# !uv pip list
# Out:
# Using Python 3.11.15 environment at: /Users/saraprochazkova/Desktop/PRG_cv_12/.venv
# Package                   Version
# ------------------------- -----------
# anyio                     4.13.0
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2026.4.22
# cffi                      2.0.0
# charset-normalizer        3.4.7
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fonttools                 4.62.1
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.13
# iniconfig                 2.3.0
# ipykernel                 7.2.0
# ipython                   9.13.0
# ipython-pygments-lexers   1.1.1
# ipywidgets                8.1.8
# isoduration               20.11.0
# jedi                      0.19.2
# jinja2                    3.1.6
# json5                     0.14.0
# jsonpointer               3.1.1
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter-client            8.8.0
# jupyter-console           6.6.3
# jupyter-core              5.9.1
# jupyter-events            0.12.1
# jupyter-lsp               2.3.1
# jupyter-server            2.17.0
# jupyter-server-terminals  0.5.4
# jupyterlab                4.5.6
# jupyterlab-pygments       0.3.0
# jupyterlab-server         2.28.0
# jupyterlab-widgets        3.0.16
# kiwisolver                1.5.0
# lark                      1.3.1
# markupsafe                3.0.3
# matplotlib                3.10.9
# matplotlib-inline         0.2.1
# mistune                   3.2.0
# nbclient                  0.10.4
# nbconvert                 7.17.1
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.5.5
# notebook-shim             0.2.4
# numpy                     2.4.4
# overrides                 7.7.0
# packaging                 26.2
# pandocfilters             1.5.1
# parso                     0.8.6
# pexpect                   4.9.0
# pillow                    12.2.0
# pip                       26.1
# platformdirs              4.9.6
# pluggy                    1.6.0
# prometheus-client         0.25.0
# prompt-toolkit            3.0.52
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure-eval                 0.2.3
# pycparser                 3.0
# pygments                  2.20.0
# pyparsing                 3.3.2
# pytest                    9.0.3
# python-dateutil           2.9.0.post0
# python-json-logger        4.1.0
# pyyaml                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.33.1
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.30.0
# send2trash                2.1.0
# setuptools                82.0.1
# six                       1.17.0
# soupsieve                 2.8.3
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.5.5
# traitlets                 5.14.3
# typing-extensions         4.15.0
# tzdata                    2026.2
# uri-template              1.3.0
# urllib3                   2.6.3
# wcwidth                   0.6.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# widgetsnbextension        4.0.15

# %% [markdown]
# + Záměrné rozbití stavu
